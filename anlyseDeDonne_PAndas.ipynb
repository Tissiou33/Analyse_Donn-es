# %% [markdown]
# IMPORTATION DE PANDAS MODULE POUR L'ANALYSE DE DONNEES EN PYTHON

# %%
import pandas as pd

# %% [markdown]
# lecture du dataset

# %%
 fp = 'https://bit.ly/bitcoin-purchases'
 print(fp) #pour aller voir la dataset
# Out:
# https://bit.ly/bitcoin-purchases

# %%
df = pd.read_csv(fp)

# %% [markdown]
# # . head ()
# pour afficher les 5 premières lignes (on peut préciser dans les parathèses le nombre de ligne qu'on désire afficher )

# %%
df.head(20)
# Out:
#                        bitcoin address wire amount          credit card
# 0   1HeUNvQfhjn8afvjMrMEX5VQB5zy8AacXZ    $2268.82  6759241310493014168
# 1   18xA8uEzQsEQpyfJWrrLmnu72ut7p2GgeU    $4590.27     6394078189900621
# 2   1CPLebXd6VKdEmD6xsVByYDbsyhkZ4XzrE    $6160.48     3539006321388994
# 3   1ESn9zPPwAExS98jqhjkDPd7tGeoevL42u    $6647.19     3560801557252993
# 4   1JLYsDExCUsEPrN6vNsEgJubJE4xqWtqhp    $3759.40     5349906235596126
# 5   1DouABjUPY9kwjrURBcxbuHCFPf4Ez8mK3     $801.71     5610792181507628
# 6   16ApQMXUnLm7rpDhR7NR9spnGod8ZwujHG    $8800.59     3579352932522667
# 7   1LyrDC2F8HKGKVnSvaFRJpD3Sid58M1vtD    $2028.37     4175006143352332
# 8   1AatD7DNnqYp5hXfpUX9YtYLCZS8jZoT2F    $2049.65     3554198007273630
# 9   19PWRWaR7ezDMGbqCzZnynEsjQL4DS7rvK    $4123.85     6761400718131582
# 10  1MzwExwSxAHZNBU4GEB5LDD9D1kFWXzg9x    $5103.21      374283559822283
# 11  1Ja7NooaRswreuHEwTsDMB5ESooiqbn9RE     $744.09     3557899026100830
# ...

# %% [markdown]
# #.shape
# affiche les dimension du dataframe sous le format (nb_ligne , nb_colonne )

# %%
df.shape
# Out:
# (1000, 3)

# %%
df.dtypes
# Out:
# bitcoin address    object
# wire amount        object
# credit card         int64
# dtype: object

# %%
df.tail(10)
# Out:
#                         bitcoin address wire amount          credit card
# 990  17B397j2fFKLqUSoDeaeyfTgGzXrNsyqyA    $5318.90     6372969672308171
# 991  13PVVhEpa4TsXvJR6pFd9DMQ57dMmtxyFe    $7896.91  6333365268298539041
# 992  13KLy53gSYSbQ3hxDQKXjeiK1YehmY9ZDb    $8533.90     5100171806507940
# 993  1PUcbpVG5D4xg1NHuSM9AjWkr4isx3be75    $9494.23      373560931229878
# 994  1EksnNf5papA1F8FzeYEjZpwmpwWkysKEZ    $3376.50      201940685820239
# 995  138k9bHDuCABrp62m3jx7qN7GpLmH1tau1    $8777.99     6395533880416383
# 996  133bMbCx4XumvjzZCctexFdWFtc8AVe92T    $7614.59     5100136128250214
# 997  1EbNemXSs9jnJuTHg3JFs3sVsCpMVmkZzg    $1710.21  4911312234445162581
# 998  1ACsxcM3utWGaGtTKBndk7S68KX7bMQCaX    $5240.64  5038080137024268375
# 999  16PZEa57oL1MEMECPRYf8bwPAttqtuSaVj    $5672.95     4903401043022953

# %% [markdown]
# pour afficher la colonne 'wire amount' sans le "$"

# %%
print(df['wire amount'].str.replace('$',''))
# Out:
# 0      2268.82
# 1      4590.27
# 2      6160.48
# 3      6647.19
# 4      3759.40
#         ...
# 995    8777.99
# 996    7614.59
# 997    1710.21
# 998    5240.64
# 999    5672.95
# Name: wire amount, Length: 1000, dtype: object

# %%
df2 = df.copy()
df2['wire amount'] = df2['wire amount'].str.replace('$',' ').astype(float)

# %%
df2
# Out:
#                         bitcoin address  wire amount          credit card
# 0    1HeUNvQfhjn8afvjMrMEX5VQB5zy8AacXZ      2268.82  6759241310493014168
# 1    18xA8uEzQsEQpyfJWrrLmnu72ut7p2GgeU      4590.27     6394078189900621
# 2    1CPLebXd6VKdEmD6xsVByYDbsyhkZ4XzrE      6160.48     3539006321388994
# 3    1ESn9zPPwAExS98jqhjkDPd7tGeoevL42u      6647.19     3560801557252993
# 4    1JLYsDExCUsEPrN6vNsEgJubJE4xqWtqhp      3759.40     5349906235596126
# ..                                  ...          ...                  ...
# 995  138k9bHDuCABrp62m3jx7qN7GpLmH1tau1      8777.99     6395533880416383
# 996  133bMbCx4XumvjzZCctexFdWFtc8AVe92T      7614.59     5100136128250214
# 997  1EbNemXSs9jnJuTHg3JFs3sVsCpMVmkZzg      1710.21  4911312234445162581
# 998  1ACsxcM3utWGaGtTKBndk7S68KX7bMQCaX      5240.64  5038080137024268375
# 999  16PZEa57oL1MEMECPRYf8bwPAttqtuSaVj      5672.95     4903401043022953
#
# [1000 rows x 3 columns]

# %%
df2.dtypes
# Out:
# bitcoin address     object
# wire amount        float64
# credit card          int64
# dtype: object

# %% [markdown]
# Je vais charger un deuxième fichier où on n'a pas que des $ mais toutes les devises monétaires possibles

# %%
fp2 =  'https://bit.ly/bitcoin-purchases2'
fp2
# Out:
# 'https://bit.ly/bitcoin-purchases2'

# %%
dt = pd.read_csv(fp2)
dt.head()
# Out:
#                       bitcoin address wire amount       credit card
# 0  1J9DVMtgvnPv4KGHL2XSzoTSt5cBBL1DXe    £8356.92  3543456448666398
# 1  1HaiVQbzCTs7t1K1fckYEUi9t8ERBFRR7Q     €311,06  3584615208479876
# 2  1NGPjXfDScEUSZYajAzCkxaVApTbBHC7jP    €2032,44  6370577480710876
# 3  15cSYRTbcrxYinxNxk7VbkPLZG8nypdjy6    ¥8155.74  4508652385157398
# 4  18j2qG1DH9YduJiBiccAq8Ak897G3E4JyZ    £3265.44   374622922103592

# %% [markdown]
# comme vous pouvez le constater il y'a des $ £ ¥ €

# %% [markdown]
# plusieurs méthode s'offrent à nous pour ne pas biaiser les calculs
#
# -on peut convertir en une monaie unique ($ peut etre )
# - mais nous allons simplement choisir de d'ignorer toutes les devises

# %%
dt['wire amount'] = dt['wire amount'].str.replace(',', '.')

# %% [markdown]
# NOUS AVONS RETIRE alors les devise .

# %%
dt2 = dt.copy()
dt2['wire amount'] = dt2['wire amount'].str.replace('$', ' ')
dt2['wire amount'] = dt2['wire amount'].str.replace('£', ' ')
dt2['wire amount'] = dt2['wire amount'].str.replace('¥', ' ')
dt2['wire amount'] = dt2['wire amount'].str.replace('€', ' ')
dt2['wire amount'] = dt2['wire amount'].astype(float)
dt2.head(20)
# Out:
#                        bitcoin address  wire amount       credit card
# 0   1J9DVMtgvnPv4KGHL2XSzoTSt5cBBL1DXe      8356.92  3543456448666398
# 1   1HaiVQbzCTs7t1K1fckYEUi9t8ERBFRR7Q       311.06  3584615208479876
# 2   1NGPjXfDScEUSZYajAzCkxaVApTbBHC7jP      2032.44  6370577480710876
# 3   15cSYRTbcrxYinxNxk7VbkPLZG8nypdjy6      8155.74  4508652385157398
# 4   18j2qG1DH9YduJiBiccAq8Ak897G3E4JyZ      3265.44   374622922103592
# 5   17js1X5yhuGgcianZctDuZCYN9MhZjemMJ      7582.61  3548758788344311
# 6   13hzSfBxdQDs4qQTBKJefZNa3BBBUpdsQM      6091.71  5411272786938057
# 7   13FxRMKPxyjRuHXgxPJyJxuu6UFB1PMHbJ      4018.08  3574760573036422
# 8   1DupqrXnspxMEL6RRfFSL7Fzbce3V3uBaw      7719.31  5007662202119789
# 9   18wq7MMetvLQ12S5aVSFp1ztkJASy2ADrH       657.75  5108759983537631
# 10  1C5WyUFn7s2p9fjbhgSLTUSeBXZDqbsTn1      7820.39  3565621670096563
# 11  1JZiTsy8EHr5a5f7hx5vp6LQ9vpStGUZK2      5291.92  3555777049792746
# ...

# %% [markdown]
# Le retrait des devises
#
# Cela n'est pas bon à faire donc pour garder cette infos nous allons créer une nouvelle colonne pour sotocker les devise

# %% [markdown]
# on considère la colonne 'wire amount' comme un tableau et on veut retourner donc le premier caractères qui n'est rien d'autre que la devise

# %%
dt['wire amount'].str.get(0)
# Out:
# 0      £
# 1      €
# 2      €
# 3      ¥
# 4      £
#       ..
# 995    ¥
# 996    €
# 997    €
# 998    $
# 999    $
# Name: wire amount, Length: 1000, dtype: object

# %% [markdown]
# NOUS ALLONS ALORS CREER UNE NOUVELLE COLONNE 'DEVISE'

# %%
dt['devise'] = dt['wire amount'].str.get(0)
dt.head()
# Out:
#                       bitcoin address wire amount       credit card devise
# 0  1J9DVMtgvnPv4KGHL2XSzoTSt5cBBL1DXe    £8356.92  3543456448666398      £
# 1  1HaiVQbzCTs7t1K1fckYEUi9t8ERBFRR7Q     €311.06  3584615208479876      €
# 2  1NGPjXfDScEUSZYajAzCkxaVApTbBHC7jP    €2032.44  6370577480710876      €
# 3  15cSYRTbcrxYinxNxk7VbkPLZG8nypdjy6    ¥8155.74  4508652385157398      ¥
# 4  18j2qG1DH9YduJiBiccAq8Ak897G3E4JyZ    £3265.44   374622922103592      £

# %%
dt['wire amount'] =  dt['wire amount'].str.slice(1,None)
dt['wire amount'].astype(float)
# Out:
# 0      8356.92
# 1       311.06
# 2      2032.44
# 3      8155.74
# 4      3265.44
#         ...
# 995     844.68
# 996    1433.63
# 997    3814.11
# 998    2900.85
# 999    1587.16
# Name: wire amount, Length: 1000, dtype: float64

# %%
dt.head()
# Out:
#                       bitcoin address wire amount       credit card devise
# 0  1J9DVMtgvnPv4KGHL2XSzoTSt5cBBL1DXe     8356.92  3543456448666398      £
# 1  1HaiVQbzCTs7t1K1fckYEUi9t8ERBFRR7Q      311.06  3584615208479876      €
# 2  1NGPjXfDScEUSZYajAzCkxaVApTbBHC7jP     2032.44  6370577480710876      €
# 3  15cSYRTbcrxYinxNxk7VbkPLZG8nypdjy6     8155.74  4508652385157398      ¥
# 4  18j2qG1DH9YduJiBiccAq8Ak897G3E4JyZ     3265.44   374622922103592      £

# %%
dt.dtypes
# Out:
# bitcoin address    object
# wire amount        object
# credit card         int64
# devise             object
# dtype: object

# %% [markdown]
# #passons à une nouvelle etapes

# %%
fp = 'https://bit.ly/felonies-dataset'
print(fp)
# Out:
# https://bit.ly/felonies-dataset

# %%
dd = pd.read_csv(fp)
dd.head()
# Out:
#         Date of Arrest  Age Convicted
# 0  2014-07-16 14:59:18   77       Yes
# 1  2002-12-19 22:17:59   28       Yes
# 2  1994-06-28 09:31:40   21        No
# 3  1985-05-14 09:52:17   45       Yes
# 4  1985-05-25 14:06:28   39       Yes

# %%
dd['Age'].min()
# Out:
# 10

# %%
dd['Age'].max()
# Out:
# 99

# %% [markdown]
# #.decribe()
# permet d'avoir les stats d'une colonnes ie la moyenne , la somme , le min , le max .....

# %%
dd['Age'].describe()
# Out:
# count    1000.000000
# mean       54.605000
# std        25.225172
# min        10.000000
# 25%        33.000000
# 50%        53.000000
# 75%        76.000000
# max        99.000000
# Name: Age, dtype: float64

# %%
dd2 =  dd.copy()
dd2['catégorie'] =  pd.cut(dd2['Age'],bins=[9, 13, 20, 70, 100],labels = ['enfant','adolescente','adulte','Tier_age'])
dd2.head()
# Out:
#         Date of Arrest  Age Convicted catégorie
# 0  2014-07-16 14:59:18   77       Yes  Tier_age
# 1  2002-12-19 22:17:59   28       Yes    adulte
# 2  1994-06-28 09:31:40   21        No    adulte
# 3  1985-05-14 09:52:17   45       Yes    adulte
# 4  1985-05-25 14:06:28   39       Yes    adulte

# %%
# Calculer la moyenne de la colonne 'Age'
mean_age = dd['Age'].mean()
mean_age
# Out:
# np.float64(54.605)

# %%
# compter le nombre de valeurs manquantes dans chaque colonne
dd2.isnull().sum()
# Out:
# Date of Arrest    0
# Age               0
# Convicted         0
# catégorie         0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# Calculate the value counts for the 'catégorie' column
category_counts = dd2['catégorie'].value_counts()

# Create a pie chart
plt.figure(figsize=(4, 4))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=180)
plt.title('Distribution de la catégorie d\'age ')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
